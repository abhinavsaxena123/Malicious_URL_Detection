# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('preprocessed_data.csv', low_memory=False)
df.head(5)
# Out:
#    Unnamed: 0                                                url        type  \
# 0           0                                   br-icloud.com.br    phishing
# 1           1                mp3raid.com/music/krizz_kaliko.html      benign
# 2           2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3           3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4           4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#    url_len  use_of_ip  domain  count_https  count_http  abnormal_url  @  ...  \
# 0       16          0  com.br            0           0             0  0  ...
# 1       35          0     com            0           0             0  0  ...
# 2       31          0     org            0           0             0  0  ...
# 3       88          0      be            0           1             1  0  ...
# 4      235          0     net            0           1             1  0  ...
#
# ...

# %%
#df['url'].iloc[115]

# %%
#df[df['type']=='malware']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'url', 'type', 'url_len', 'use_of_ip', 'domain',
#        'count_https', 'count_http', 'abnormal_url', '@', '?', '-', '=', '.',
#        '#', '%', '+', '$', '!', '*', ',', '//', 'sum_count_special_chars',
#        'pri_domain', 'redirection', 'hostname_length', 'tld', 'tld_length',
#        'short_url', 'count_digits', 'fd_len', 'is_sus_words'],
#       dtype='object')

# %%
df.shape
# Out:
# (651191, 32)

# %%
df['type'].value_counts()
# Out:
# type
# benign        428103
# defacement     96457
# phishing       94111
# malware        32520
# Name: count, dtype: int64

# %% [markdown]
# #### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["type_code"] = le.fit_transform(df["type"])
df["type_code"].value_counts()
# Out:
# type_code
# 0    428103
# 1     96457
# 3     94111
# 2     32520
# Name: count, dtype: int64

# %% [markdown]
# #### 0 -> Benign | 1 -> Defacement | 2 -> Malware | 3 -> Phishing

# %%
df.head(2)
# Out:
#    Unnamed: 0                                  url      type  url_len  \
# 0           0                     br-icloud.com.br  phishing       16
# 1           1  mp3raid.com/music/krizz_kaliko.html    benign       35
#
#    use_of_ip  domain  count_https  count_http  abnormal_url  @  ...  \
# 0          0  com.br            0           0             0  0  ...
# 1          0     com            0           0             0  0  ...
#
#          pri_domain  redirection  hostname_length  tld  tld_length  short_url  \
# 0  br-icloud.com.br            0                0  NaN          -1          0
# 1       mp3raid.com            0                0  NaN          -1          0
#
#    count_digits  fd_len  is_sus_words  type_code
# 0             0       0             0          3
# 1             1       5             0          0
#
# [2 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'url', 'type', 'url_len', 'use_of_ip', 'domain',
#        'count_https', 'count_http', 'abnormal_url', '@', '?', '-', '=', '.',
#        '#', '%', '+', '$', '!', '*', ',', '//', 'sum_count_special_chars',
#        'pri_domain', 'redirection', 'hostname_length', 'tld', 'tld_length',
#        'short_url', 'count_digits', 'fd_len', 'is_sus_words', 'type_code'],
#       dtype='object')

# %% [markdown]
# #### Predictor Variables

# %%
X = df[['url_len', 'use_of_ip', 'count_https', 'count_http', 'abnormal_url', '@', '?', 
    '-', '=', '.','#', '%', '+', '$', '!', '*', ',', '//', 'sum_count_special_chars', 
    'redirection', 'short_url', 'count_digits' , 'hostname_length', 'tld_length',
    'fd_len', 'is_sus_words'
    ]]

# %%
X.shape
# Out:
# (651191, 26)

# %% [markdown]
# #### Target Variable

# %%
y = df['type_code']

# %%
y.shape
# Out:
# (651191,)

# %% [markdown]
# ### Splitting the Dataset

# %% [markdown]
# #### 80% Training Set and 20% Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size= 0.2 , shuffle = True, random_state = 42)

# %%
print('Training Set Shape')
print(X_train.shape)
print(Y_train.shape)
print()
print('Test Set Shape')
print(X_test.shape)
print(Y_test.shape)
# Out:
# Training Set Shape
# (520952, 26)
# (520952,)
#
# Test Set Shape
# (130239, 26)
# (130239,)

# %% [markdown]
# ### Model Building

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score,classification_report,confusion_matrix, ConfusionMatrixDisplay

def evaluate_model(y_true, y_pred, model_name="Model", average='macro'):
    
    # Calculating metrics
    accuracy = round(accuracy_score(y_true, y_pred) * 100, 2)
    f1 = round(f1_score(y_true, y_pred, average=average,zero_division=0) * 100, 2)
    recall = round(recall_score(y_true, y_pred, average=average,zero_division=0) * 100, 2)
    precision = round(precision_score(y_true, y_pred, average=average,zero_division=0) * 100, 2)

    # Printing results
    print(f"{model_name} Evaluation Metrics:")
    print(f"Accuracy: {accuracy}%")
    print(f"F1 Score: {f1}%")
    print(f"Recall: {recall}%")
    print(f"Precision: {precision}%")
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, zero_division=0))

    return {
        "accuracy": accuracy,
        "f1_score": f1,
        "recall": recall,
        "precision": precision,
    }

# %%
# Function to store metrics score for each model...
model_score = {}

# %%
def plot_confusion_matrix(cm,title='Confusion Matrix',cmap=plt.cm.Reds,display_metrics=True):
    plt.figure(figsize=(7, 5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    #0 -> Benign | 1 -> Defacement | 2 -> Malware | 3 -> Phishing
    classes = ['Benign', 'Defacement', 'Malware', 'Phishing'] 
    plt.xticks(ticks=np.arange(len(classes)), labels=classes)
    plt.yticks(ticks=np.arange(len(classes)), labels=classes)

     # Add text annotations to each cell
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, f'{cm[i, j]}',
                     ha='center', va='center',
                     color='white' if cm[i, j] > cm.max() / 2. else 'black')
            
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.grid(False)

# %% [markdown]
# ### 1. Multinomial Naive Baiyes

# %% [markdown]
# * The Multinomial Naive Bayes model is designed to work with discrete, non-negative feature values. Since the tld_length column contains negative value, it would not be appropriate to feed it into a Multinomial Naive Bayes model.

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
X_df = X_train.drop(['tld_length'], axis = 1)
X_test_df = X_test.drop(['tld_length'], axis = 1)

# %%
mnb = MultinomialNB()
mnb.fit(X_df, Y_train)
# Out:
# MultinomialNB()

# %%
# Make predictions
y_pred_mnb= mnb.predict(X_test_df)

metrics = evaluate_model(Y_test, y_pred_mnb, model_name="MNB")
model_score["MNB"] = list(metrics.values())
# Out:
# MNB Evaluation Metrics:
# Accuracy: 78.92%
# F1 Score: 60.78%
# Recall: 63.88%
# Precision: 61.42%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89     85778
#            1       0.72      0.92      0.81     19104
#            2       0.61      0.63      0.62      6521
#            3       0.28      0.07      0.12     18836
#
#     accuracy                           0.79    130239
#    macro avg       0.61      0.64      0.61    130239
# weighted avg       0.73      0.79      0.75    130239

# %%
mnb_cm = confusion_matrix(Y_test, y_pred_mnb)
plot_confusion_matrix(mnb_cm)

# %% [markdown]
# ### 2. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(max_depth=6)
dtc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
# Make predictions
y_pred_dtc = dtc.predict(X_test)

metrics = evaluate_model(Y_test, y_pred_dtc, model_name="Decision Tree")
model_score["Decision Tree"] = list(metrics.values())
# Out:
# Decision Tree Evaluation Metrics:
# Accuracy: 85.4%
# F1 Score: 74.47%
# Recall: 72.21%
# Precision: 82.9%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92     85778
#            1       0.82      0.93      0.87     19104
#            2       0.89      0.70      0.78      6521
#            3       0.74      0.28      0.40     18836
#
#     accuracy                           0.85    130239
#    macro avg       0.83      0.72      0.74    130239
# weighted avg       0.84      0.85      0.83    130239

# %% [markdown]
# ### Using Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],       # Criteria to split
    'max_depth': [None, 5, 6, 8, 10], # Maximum depth of the tree
    'min_samples_split': [2, 5, 10], # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],    # Minimum number of samples required to be at a leaf node
    'max_features': [None, 'sqrt', 'log2'] # Number of features to consider when looking for the best split
}

dtc = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator=dtc, param_grid=param_grid, 
                           cv=5, n_jobs=-1, verbose=2, scoring='accuracy')

grid_search.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 6, 8, 10],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy', verbose=2)

# %%
# Get the best estimator
best_dtc = grid_search.best_estimator_
print(best_dtc)

# Make predictions using the best estimator
y_pred_dtc = best_dtc.predict(X_test)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_leaf=2)

# %%
metrics = evaluate_model(Y_test, y_pred_dtc, 
                         model_name="Decision Tree Classifier with GridSearchCV")

model_score["Decision Tree Classifier with GridSearchCV"] = list(metrics.values())
# Out:
# Decision Tree Classifier with GridSearchCV Evaluation Metrics:
# Accuracy: 90.66%
# F1 Score: 87.28%
# Recall: 85.75%
# Precision: 89.68%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     85778
#            1       0.96      0.98      0.97     19104
#            2       0.95      0.93      0.94      6521
#            3       0.76      0.55      0.64     18836
#
#     accuracy                           0.91    130239
#    macro avg       0.90      0.86      0.87    130239
# weighted avg       0.90      0.91      0.90    130239

# %%
dtc_cm = confusion_matrix(Y_test, y_pred_dtc)
plot_confusion_matrix(dtc_cm)

# %% [markdown]
# 1. An accuracy of 91% is quite high, indicating that the model performs well on the entire dataset.
# 2. For Class 3 also recall and f1-score increased.

# %% [markdown]
# ### 3. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(max_depth=6)
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=6)

# %%
# Making predictions
y_pred_rf = rf.predict(X_test)

metrics = evaluate_model(Y_test, y_pred_rf, model_name="Random Forest")
model_score["Random Forest"] = list(metrics.values())
# Out:
# Random Forest Evaluation Metrics:
# Accuracy: 84.46%
# F1 Score: 68.61%
# Recall: 68.34%
# Precision: 88.34%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92     85778
#            1       0.78      0.99      0.87     19104
#            2       0.97      0.66      0.79      6521
#            3       0.93      0.09      0.17     18836
#
#     accuracy                           0.84    130239
#    macro avg       0.88      0.68      0.69    130239
# weighted avg       0.86      0.84      0.80    130239

# %%
rf_cm = confusion_matrix(Y_test, y_pred_rf)
plot_confusion_matrix(rf_cm)

# %% [markdown]
# 1. Accuracy got reduced and the model peforms poorly for class 3 i.e Phishing.

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

# %%
xgb_model = xgb.XGBClassifier(
    objective='multi:softmax',  # For multi-class classification
    num_class=4,               
    eval_metric='mlogloss',     # Evaluation metric for multi-class classification
    learning_rate=0.01,
    n_estimators=100,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8
)

# %%
xgb_model.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_class=4, num_parallel_tree=None, ...)

# %%
# Make predictions
xgb_preds = xgb_model.predict(X_test)

metrics = evaluate_model(Y_test, xgb_preds, model_name="XGBoost")
model_score["XGBoost"] = list(metrics.values())
# Out:
# XGBoost Evaluation Metrics:
# Accuracy: 84.47%
# F1 Score: 68.86%
# Recall: 68.54%
# Precision: 85.42%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92     85778
#            1       0.79      0.98      0.87     19104
#            2       0.93      0.67      0.78      6521
#            3       0.84      0.10      0.19     18836
#
#     accuracy                           0.84    130239
#    macro avg       0.85      0.69      0.69    130239
# weighted avg       0.85      0.84      0.80    130239

# %%
xgb_cm = confusion_matrix(Y_test, xgb_preds)
plot_confusion_matrix(xgb_cm)

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(random_state=42)

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1],
    'algorithm': ['SAMME']  
}

grid_search = GridSearchCV(estimator=ada, param_grid=param_grid, scoring='accuracy', cv=5, n_jobs=-1)

# Fitting GridSearchCV to the training data
grid_search.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=42), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME'],
#                          'learning_rate': [0.01, 0.1, 1],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy')

# %%
# Getting the best parameters
best_params = grid_search.best_params_
print("Best Parameters found by GridSearchCV:", best_params)
# Getting the best estimator
best_ada = grid_search.best_estimator_
print(best_ada)

# Make predictions
ada_preds = best_ada.predict(X_test)

metrics = evaluate_model(Y_test, ada_preds, model_name="AdaBoost")
model_score["AdaBoost"] = list(metrics.values())
# Out:
# Best Parameters found by GridSearchCV: {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 200}
# AdaBoostClassifier(algorithm='SAMME', learning_rate=1, n_estimators=200,
#                    random_state=42)
# AdaBoost Evaluation Metrics:
# Accuracy: 81.81%
# F1 Score: 68.63%
# Recall: 65.96%
# Precision: 73.36%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90     85778
#            1       0.85      0.88      0.86     19104
#            2       0.77      0.50      0.60      6521
#            3       0.45      0.32      0.38     18836
#
#     accuracy                           0.82    130239
#    macro avg       0.73      0.66      0.69    130239
# weighted avg       0.80      0.82      0.81    130239

# %%
ada_cm = confusion_matrix(Y_test, ada_preds)
plot_confusion_matrix(ada_cm)

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, Sequential
from tensorflow.keras import layers, models, optimizers, losses

# %%
model_ANN = Sequential([
    layers.InputLayer(input_shape=(X_train.shape[1],)), 
    
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),  # Dropout to prevent overfitting
    
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(4, activation='softmax')  # 4 output classes with softmax
])

# %%
model_ANN.compile(
    optimizer=optimizers.Adam(),
    loss=losses.SparseCategoricalCrossentropy(),
     metrics=['accuracy']
)
model_ANN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               3456
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# ...
# Total params: 69,892
# Trainable params: 69,892
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model_ANN.fit(X_train, Y_train, epochs=10, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 13024/13024 [==============================] - 41s 3ms/step - loss: 0.4091 - accuracy: 0.8438 - val_loss: 0.3278 - val_accuracy: 0.8705
# Epoch 2/10
# 13024/13024 [==============================] - 40s 3ms/step - loss: 0.3452 - accuracy: 0.8641 - val_loss: 0.3092 - val_accuracy: 0.8752
# Epoch 3/10
# 13024/13024 [==============================] - 38s 3ms/step - loss: 0.3349 - accuracy: 0.8685 - val_loss: 0.3025 - val_accuracy: 0.8782
# Epoch 4/10
# 13024/13024 [==============================] - 39s 3ms/step - loss: 0.3289 - accuracy: 0.8708 - val_loss: 0.2925 - val_accuracy: 0.8809
# Epoch 5/10
# 13024/13024 [==============================] - 34s 3ms/step - loss: 0.3259 - accuracy: 0.8723 - val_loss: 0.2938 - val_accuracy: 0.8825
# Epoch 6/10
# 13024/13024 [==============================] - 37s 3ms/step - loss: 0.3233 - accuracy: 0.8730 - val_loss: 0.2885 - val_accuracy: 0.8833
# Epoch 7/10
# ...

# %%
# Retrieving training and validation metrics
history_dict = history.history
epochs = range(1, len(history_dict['loss']) + 1)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, history_dict['loss'], 'bo', label='Training loss')
plt.plot(epochs, history_dict['val_loss'], 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 2)
plt.plot(epochs, history_dict['accuracy'], 'bo', label='Training accuracy')
plt.plot(epochs, history_dict['val_accuracy'], 'b', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred_prob_ann = model_ANN.predict(X_test)
predicted_classes = y_pred_prob_ann.argmax(axis=1)
# Out:
# 4070/4070 [==============================] - 5s 1ms/step

# %%
metrics = evaluate_model(Y_test, predicted_classes, model_name="ANN")
model_score["ANN"] = list(metrics.values())
# Out:
# ANN Evaluation Metrics:
# Accuracy: 88.32%
# F1 Score: 81.61%
# Recall: 79.16%
# Precision: 86.7%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93     85778
#            1       0.88      0.98      0.93     19104
#            2       0.95      0.78      0.86      6521
#            3       0.74      0.43      0.55     18836
#
#     accuracy                           0.88    130239
#    macro avg       0.87      0.79      0.82    130239
# weighted avg       0.87      0.88      0.87    130239

# %%
ann_cm = confusion_matrix(Y_test, predicted_classes)
plot_confusion_matrix(ann_cm)

# %%
model_score
# Out:
# {'Decision Tree': [85.4, 74.47, 72.21, 82.9],
#  'Decision Tree Classifier with GridSearchCV': [90.66, 87.28, 85.75, 89.68]}

# %%
score_df = pd.DataFrame(model_score).transpose()
score_df.rename(columns = {0 :'Accuracy', 1:'F1' , 2: 'Recall', 3:'precision_score'}, inplace = True)
score_df.sort_values(by = 'Recall', ascending = False, inplace = True)

# %%
score_df
# Out:
#                                             Accuracy     F1  Recall  \
# Decision Tree Classifier with GridSearchCV     90.66  87.28   85.76
# ANN                                            88.32  81.61   79.16
# Decision Tree                                  85.40  74.47   72.21
# XGBoost                                        84.47  68.86   68.54
# Random Forest                                  84.46  68.61   68.34
# AdaBoost                                       81.81  68.63   65.96
# MNB                                            78.92  60.78   63.88
#
#                                             precision_score
# Decision Tree Classifier with GridSearchCV            89.66
# ANN                                                   86.70
# Decision Tree                                         82.90
# XGBoost                                               85.42
# Random Forest                                         88.34
# AdaBoost                                              73.36
# ...

# %%
fig = plt.figure(figsize=(20,5), facecolor = '#e6dfeb')
axes = plt.subplot2grid((1,1),(0,0))

sns.heatmap(
    data = score_df, cmap='YlGnBu', annot = True,fmt='.2f', annot_kws={"size": 12},  
    cbar_kws={"shrink": 0.8},  linewidths=0.5,  linecolor='white' ,
      )

plt.xlabel('Metrics', fontsize=17)
plt.ylabel('Models', fontsize=17)
plt.title('Model Performance Metrics Heatmap', fontsize=18)

plt.show()

# %% [markdown]
# ### Saving Models

# %%
import pickle

# %%
#Saving the best classifier
pickle.dump(best_dtc, open('dtc.pkl', 'wb'))

# %%
# Creating a dictionary to hold the models
models = {
    'AdaBoost': best_ada,
    'RandomForest': rf,
    'MNB': mnb,
    'DecisionTree':best_dtc, #through grid search
    'ANN': model_ANN,
}

# %%
# Saving all models to a file using pickle
with open('multiple_models.pkl', 'wb') as model_file:
    pickle.dump(models, model_file)

print("Models saved successfully.")
# Out:
# INFO:tensorflow:Assets written to: ram://d5e58507-5aa1-476e-b92c-ca9f124442bb/assets
# Models saved successfully.
